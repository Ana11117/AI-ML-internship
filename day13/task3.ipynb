# %%
import pandas as pd
import numpy as np

data = {
    'SquareFootage': [1200, 1500, 1800, 2000, 2200, 2500, 2700, 3000, 3200, 3500],
    'Price': [200000, 250000, 280000, 310000, 330000, 400000, 420000, 480000, 500000, 550000],
    'Bedrooms': [2, 3, 3, 3, 4, 4, 4, 5, 5, 5],
    'Bathrooms': [1, 2, 2, 2, 3, 3, 3, 4, 4, 4]
}

df = pd.DataFrame(data)
df.head()
# Out:
#    SquareFootage   Price  Bedrooms  Bathrooms
# 0           1200  200000         2          1
# 1           1500  250000         3          2
# 2           1800  280000         3          2
# 3           2000  310000         3          2
# 4           2200  330000         4          3

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Generate correlation matrix
corr_matrix = df.corr()

# Display correlation values
print(corr_matrix)
# Out:
#                SquareFootage     Price  Bedrooms  Bathrooms
# SquareFootage       1.000000  0.997162  0.960016   0.960016
# Price               0.997162  1.000000  0.957959   0.957959
# Bedrooms            0.960016  0.957959  1.000000   1.000000
# Bathrooms           0.960016  0.957959  1.000000   1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')

plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.boxplot(y='Price', data=df)

plt.title("Boxplot of Price")
plt.show()
