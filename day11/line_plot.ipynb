# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
months=[1,2,3,4,5]
revenue=[2000,4500,4000,7500,9000]
plt.plot(months,revenue,color="purple")
plt.title("Monthly Revenue Growth")
plt.xlabel("month")
plt.ylabel("revenue")
# Out:
# Text(0, 0.5, 'revenue')
