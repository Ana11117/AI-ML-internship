# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
study_hours=[1,2,3,4,5,6,7,8]
scores=[50,55,65,70,75,85,90,95]
plt.scatter(study_hours,scores)
plt.title("study and scores")
plt.xlabel("study_hours")
plt.ylabel("scores")
# Out:
# Text(0, 0.5, 'scores')
