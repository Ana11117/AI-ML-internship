# %%
d={"id":1,
  "name":"ana",
  "Branch":"AI"}
d.get("id")
# Out:
# 1

# %%
d["id"]
# Out:
# 1

# %%
d.update({"age":22})

# %%
d
# Out:
# {'id': 1, 'name': 'ana', 'Branch': 'AI', 'age': 22}

# %%
d["id"]=2

# %%
d
# Out:
# {'id': 2, 'name': 'ana', 'Branch': 'AI', 'age': 22}

# %%
d.pop("age")
# Out:
# 22

# %%
d

# %%
d.keys()
# Out:
# dict_keys(['id', 'name', 'Branch'])

# %%
d.values()
# Out:
# dict_values([2, 'ana', 'AI'])

# %%
d.popitem()
# Out:
# ('Branch', 'AI')

# %%
d
# Out:
# {'id': 2, 'name': 'ana'}

# %%
d.items()
# Out:
# dict_items([('id', 2), ('name', 'ana')])

# %%
d.update({"branch":"AI/ML","age":23})

# %%
d
# Out:
# {'id': 2, 'name': 'ana', 'branch': 'AI/ML', 'age': 23}
